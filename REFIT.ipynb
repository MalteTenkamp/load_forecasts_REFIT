# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
house = pd.read_csv('House_1.csv', nrows = 1000000)

# %%
house.head()
# Out:
#                   Time        Unix  Aggregate  Appliance1  Appliance2
# 0  2013-10-09 13:06:17  1381323977        523          74           0  \
# 1  2013-10-09 13:06:31  1381323991        526          75           0
# 2  2013-10-09 13:06:46  1381324006        540          74           0
# 3  2013-10-09 13:07:01  1381324021        532          74           0
# 4  2013-10-09 13:07:15  1381324035        540          74           0
#
#    Appliance3  Appliance4  Appliance5  Appliance6  Appliance7  Appliance8
# 0          69           0           0           0           0           0  \
# 1          69           0           0           0           0           0
# 2          68           0           0           0           0           0
# 3          68           0           0           0           0           0
# 4          69           0           0           0           0           0
#
#    Appliance9
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
house2 = pd.read_csv('House_2.csv', nrows = 10000000)

# %%
house2.tail(50)
# Out:
#                         Time        Unix  Aggregate  Appliance1  Appliance2
# 5733476  2015-05-28 08:00:14  1432800014        340          82         240  \
# 5733477  2015-05-28 08:00:20  1432800020        341          82         193
# 5733478  2015-05-28 08:00:27  1432800027        341          82         228
# 5733479  2015-05-28 08:00:34  1432800034        300          82         194
# 5733480  2015-05-28 08:00:40  1432800040        300          82         227
# 5733481  2015-05-28 08:00:47  1432800047        320          82         208
# 5733482  2015-05-28 08:00:54  1432800054        307          82         210
# 5733483  2015-05-28 08:01:01  1432800061        331          82         210
# 5733484  2015-05-28 08:01:07  1432800067        331          82         200
# 5733485  2015-05-28 08:01:14  1432800074        313          82         211
# 5733486  2015-05-28 08:01:21  1432800081        278          82           6
# ...

# %%
time_aggregate = house2[['Time', 'Aggregate']].copy()

# %%
print(time_aggregate.dtypes)
# Out:
# Time         object
# Aggregate     int64
# dtype: object

# %%
time_aggregate['Time'] = pd.to_datetime(time_aggregate['Time'])

# %%
time_aggregate.set_index('Time', inplace=True)

# %%
time_aggregate['Aggregate'].plot()
# Out:
# <Axes: xlabel='Time'>

# %%
time_aggregate['Aggregate'].quantile(.995)
# Out:
# 10103.0

# %%
house2.describe()
# Out:
#                Unix     Aggregate    Appliance1    Appliance2    Appliance3
# count  5.733526e+06  5.733526e+06  5.733526e+06  5.733526e+06  5.733526e+06  \
# mean   1.409809e+09  4.651023e+02  3.576811e+01  1.826877e+01  6.154452e+01
# std    1.401948e+07  1.062579e+03  4.565278e+01  1.743028e+02  3.523295e+02
# min    1.379456e+09  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.399690e+09  1.080000e+02  1.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.410659e+09  1.680000e+02  1.000000e+00  0.000000e+00  0.000000e+00
# 75%    1.421611e+09  3.310000e+02  8.400000e+01  0.000000e+00  0.000000e+00
# max    1.432800e+09  2.459500e+04  1.690000e+03  3.584000e+03  3.092000e+03
#
#          Appliance4    Appliance5    Appliance6    Appliance7    Appliance8
# count  5.733526e+06  5.733526e+06  5.733526e+06  5.733526e+06  5.733526e+06  \
# mean   3.965859e+00  3.277610e+00  1.549044e+00  1.733205e+00  2.315502e+01
# ...

# %%
shortened = time_aggregate.iloc[-250000:]

# %%
start_date = '2014-06-01'
end_date = '2014-06-04'

threedays = time_aggregate[start_date:end_date]

# %%
threedays.plot(linewidth=1, figsize=(20,20))
# Out:
# <Axes: xlabel='Time'>

# %%
house2_time_index = house2.set_index('Time')

threedays_all = house2_time_index[start_date:end_date].copy()

new_column_names = {
    'Aggregate': 'Agg',
    'Appliance1': 'FF',  # Fridge-Freezer
    'Appliance2': 'WM',  # Washing Machine
    'Appliance3': 'DW',  # Dishwasher
    'Appliance4': 'TV',  # Television
    'Appliance5': 'MW',  # Microwave
    'Appliance6': 'To',  # Toaster
    'Appliance7': 'HiFi', # Hi-Fi
    'Appliance8': 'Ke',  # Kettle
    'Appliance9': 'OEF', # Oven Extractor Fan
}

threedays_all.rename(columns=new_column_names, inplace=True)

threedays_all.drop(columns=['Unix'], inplace=True)

# %%
threedays_all.plot(linewidth=1, figsize=(20,20))
#threedays_all[['FF', 'WM','DW','TV','MW','To','HiFi','Ke','OEF']].plot(linewidth=1, figsize=(20, 20))
# Out:
# <Axes: xlabel='Time'>
